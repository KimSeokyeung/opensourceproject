# %% [markdown]
# # Bicycle_Time_series_analysis

# %%
import pandas as pd
import numpy as np

# %%
df_2016_1   = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2016년_1.csv", engine='python')       # 2016_1_1 ~ 2016_7_31
df_2016_2   = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2016년_2.csv", engine='python')       # 2016_8_1 ~ 2016_10_31
df_2016_3   = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2016년_3.csv", engine='python')       # 2016_11_1 ~ 2016_12_31

df_2017_1   = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2017년_1.csv", engine='python')       # 2017_1_1 ~ 2017_3_31
df_2017_2_1 = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2017년_2분기_1.csv", engine='python') # 2017_4_1 ~ 2017_5_31
df_2017_2_2 = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2017년_2분기_2.csv", engine='python') # 2017_6_1 ~ 2017_6_30

df_2017_3_1 = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2017년_3분기_1.csv", engine='python') # 2017_7_1 ~ 2017_8_31
df_2017_3_2 = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2017년_3분기_2.csv", engine='python') # 2017_9_1 ~ 2017_9_30
df_2017_4_1 = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2017년_4분기_1.csv", engine='python') # 2017_10_1 ~ 2017_10_31
df_2017_4_2 = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2017년_4분기_2.csv", engine='python') # 2017_11_1 ~ 2017_12_31

# %%
df_2018_1_1 = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2018년_1분기1.csv", engine='python')  # 2018_1_1 ~ 2018_3_31
df_2018_2_1 = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2018년_2분기_1.csv", engine='python') # 2018_4_1 ~ 2018_4_30
df_2018_2_2 = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2018년_2분기_2.csv", engine='python') # 2018_5_1 ~ 2018_5_31
df_2018_2_3 = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2018년_2분기_3.csv", engine='python') # 2018_6_1 ~ 2018_6_15
df_2018_2_4 = pd.read_csv("서울특별시 공공자전거 대여이력 정보_2018년_2분기_4.csv", engine='python') # 2018_6_16 ~ 2018_6_30

df_201807_1 = pd.read_csv("서울특별시 공공자전거 대여정보_201807_01.csv", engine='python')           # 2018_7_1 ~ 2018_7_30

df_201807_2 = pd.read_csv("서울특별시 공공자전거 대여정보_201807_02.csv", engine='python').dropna()  # 2018_7_30 ~ 2018_7_31
df_201808   = pd.read_csv("서울특별시 공공자전거 대여정보_201808.csv", engine='python').dropna()     # 2018_8_1 ~ 2018_8_31

df_201809_1 = pd.read_csv("서울특별시 공공자전거 대여정보_201809_1.csv", engine='python')            # 2018_9_1 ~ 2018_9_23 # data missing
df_201809_2 = pd.read_csv("서울특별시 공공자전거 대여정보_201809_2.csv", engine='python').dropna()   # 2018_9_23 ~ 2018_9_30

df_201810_1 = pd.read_csv("서울특별시 공공자전거 대여정보_201810_01.csv", engine='python')           # 2018_10_1 ~ 2018_10_22
df_201810_2 = pd.read_csv("서울특별시 공공자전거 대여정보_201810_02.csv", engine='python').dropna()  # 2018_10_22 ~ 2018_10_31

df_201811   = pd.read_csv("서울특별시 공공자전거 대여정보_201811.csv", engine='python')              # 2018_11_1 ~ 2018_11_30
df_201812   = pd.read_csv("서울특별시 공공자전거 대여정보_201812.csv", engine='python')              # 2018_12_1 ~ 2018_12_31

df_201901   = pd.read_csv("서울특별시 공공자전거 대여정보_201901.csv", engine='python')              # 2019_1_1 ~ 2018_1_31

df_201902   = pd.read_csv("서울특별시 공공자전거 대여정보_201902.csv", engine='python')              # 2019_2_1 ~ 2018_2_28
df_201903   = pd.read_csv("서울특별시 공공자전거 대여정보_201903.csv", engine='python')              # 2019_3_1 ~ 2018_3_31

df_201904   = pd.read_csv("서울특별시 공공자전거 대여정보_201904.csv", engine='python')              # 2019_4_1 ~ 2019_4_30
df_201905   = pd.read_csv("서울특별시 공공자전거 대여정보_201905.csv", engine='python')              # 2019_5_1 ~ 2019_5_31

# %%
df_2016_2 = pd.merge(df_2016_1, df_2016_2, how='outer')
df2 = pd.merge(df_2016_2, df_2016_3, how='outer')

# %%
df3 = pd.merge(df_2017_1, df_2017_2_1, how='outer') ## df_2017_2_1 '' data shit;

# %%
df4 = pd.merge(df_2017_2_2, df_2017_3_1, how='outer')
df5 = pd.merge(df_2017_3_2, df_2017_4_1, how='outer')

# %%
df6 = pd.merge(df_2017_4_2, df_2018_1_1, how='outer')
df7 = pd.merge(df_2018_2_1, df_2018_2_2, how='outer')
df8 = pd.merge(df_2018_2_3, df_2018_2_4, how='outer')
df9 = pd.merge(df_2018_2_3, df_2018_2_4, how='outer')

# %%
df9
# Out:
#              '자전거번호'                 '대여일시' '대여대여소번호'                '대여대여소명'  \
# 0        'SPB-06782'  '2018-06-01 00:00:02'    '1952'          ' 천왕연지타운2단지 앞'
# 1        'SPB-04511'  '2018-06-01 00:00:08'    '1446'            ' 중랑전화국 교차로'
# 2        'SPB-10103'  '2018-06-01 00:00:08'    '2244'           '교육개발원입구 교차로'
# 3        'SPB-06223'  '2018-06-01 00:00:13'     '349'              ' 사직동주민센터'
# 4        'SPB-06325'  '2018-06-01 00:00:15'     '504'            ' 신자초교입구교차로'
# 5        'SPB-07052'  '2018-06-01 00:00:15'    '1653'              ' 노원역1번출구'
# 6        'SPB-08929'  '2018-06-01 00:00:17'     '113'         ' 홍대입구역 2번출구 앞'
# 7        'SPB-07946'  '2018-06-01 00:00:18'    '1708'     ' 보건소사거리(다비치안경창동점)'
# 8        'SPB-07672'  '2018-06-01 00:00:22'     '255'                ' 도림4거리'
# 9        'SPB-03986'  '2018-06-01 00:00:24'    '2116'             ' 에이스에이존빌딩'
# 10       'SPB-08372'  '2018-06-01 00:00:26'     '916'              ' 평생학습관 앞'
# ...

# %%
df10 = pd.merge(df_201807_1, df_201807_2, how='outer')
df11 = pd.merge(df_201808 , df_201809_1, how='outer')

# %%
df12 = pd.merge(df_201809_2, df_201810_1, how='outer')
df13 = pd.merge(df_201810_2 ,df_201811 , how='outer')

# %%
df14 = pd.merge(df_201812 , df_201901, how='outer')

# %%
df15 = pd.merge(df_201902,df_201903 , how='outer')

df16 = pd.merge(df_201904,df_201905 , how='outer')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-12-e0a872d317d9> in <module>()
#       1 df15 = pd.merge(df_201902,df_201903 , how='outer')
#       2
# ----> 3 df16 = pd.merge(df_201904,df_201905 , how='outer')
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      58                          right_index=right_index, sort=sort, suffixes=suffixes,
#      59                          copy=copy, indicator=indicator,
# ---> 60                          validate=validate)
#      61     return op.get_result()
#      62
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...
