# %%
import urllib.request
import urllib.parse
from urllib.request import Request, urlopen
from urllib.parse import urlencode,quote_plus

url = 'http://apis.data.go.kr/1750000/FireStatisticsService/FireCarelessMonthlyCrntSt?startDate=20131201&endDate=20141223&ServiceKey=wgxyy9n4C91k7EePNZttkX87gKmv%2Bso4RBo37DLRhC1bQkzVdCfeEycb8Ukn220lN0Nwxt2LM9UAyXMcWxTetQ%3D%3D'

res = requests.get(url)
text = res.text
print(text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><carelesscause>불씨,불꽃,화원방치</carelesscause><fire>298</fire><regdate>02</regdate></item><item><carelesscause>담배꽁초</carelesscause><fire>710</fire><regdate>01</regdate></item><item><carelesscause>담배꽁초</carelesscause><fire>477</fire><regdate>10</regdate></item><item><carelesscause>용접, 절단, 연마</carelesscause><fire>97</fire><regdate>01</regdate></item><item><carelesscause>불장난</carelesscause><fire>39</fire><regdate>10</regdate></item><item><carelesscause>용접, 절단, 연마</carelesscause><fire>186</fire><regdate>12</regdate></item><item><carelesscause>용접, 절단, 연마</carelesscause><fire>73</fire><regdate>02</regdate></item><item><carelesscause>음식물 조리중</carelesscause><fire>377</fire><regdate>09</regdate></item><item><carelesscause>담배꽁초</carelesscause><fire>231</fire><regdate>08</regdate></item><item><carelesscause>빨래삶기</carelesscause><fire>17<
# ...

# %%
import requests
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote


url = 'http://apis.data.go.kr/1750000/FireStatisticsService/FireCarelessMonthlyCrntSt'
queryParams = '?' + urlencode({
    quote_plus('startDate'): '20131201',
    quote_plus('endDate'): '20141223', quote_plus('ServiceKey') : 'wgxyy9n4C91k7EePNZttkX87gKmv%2Bso4RBo37DLRhC1bQkzVdCfeEycb8Ukn220lN0Nwxt2LM9UAyXMcWxTetQ%3D%3D'
})

request = Request(url+queryParams)
request.get_method = lambda : 'GET'
response_body = urlopen(request).read().decode('utf-8')

print(response_body)
        

#res = requests.get(url)
# Out:
# <OpenAPI_ServiceResponse>
# 	<cmmMsgHeader>
# 		<errMsg>SERVICE ERROR</errMsg>
# 		<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>
# 		<returnReasonCode>30</returnReasonCode>
# 	</cmmMsgHeader>
# </OpenAPI_ServiceResponse>

# %%
import requests
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote


url = 'http://apis.data.go.kr/1750000/FireStatisticsService/FireCarelessMonthlyCrntSt'
queryParams = '?' + 'startDate='+ '20131201' + '&' + 'endDate=' + '20141223' + '&' + 'ServiceKey=' + 'wgxyy9n4C91k7EePNZttkX87gKmv%2Bso4RBo37DLRhC1bQkzVdCfeEycb8Ukn220lN0Nwxt2LM9UAyXMcWxTetQ%3D%3D'

request = Request(url+queryParams)
request.get_method = lambda : 'GET'
response_body = urlopen(request).read().decode('utf-8')

print(response_body)
        

#res = requests.get(url)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><carelesscause>불씨,불꽃,화원방치</carelesscause><fire>298</fire><regdate>02</regdate></item><item><carelesscause>담배꽁초</carelesscause><fire>710</fire><regdate>01</regdate></item><item><carelesscause>담배꽁초</carelesscause><fire>477</fire><regdate>10</regdate></item><item><carelesscause>용접, 절단, 연마</carelesscause><fire>97</fire><regdate>01</regdate></item><item><carelesscause>불장난</carelesscause><fire>39</fire><regdate>10</regdate></item><item><carelesscause>용접, 절단, 연마</carelesscause><fire>186</fire><regdate>12</regdate></item><item><carelesscause>용접, 절단, 연마</carelesscause><fire>73</fire><regdate>02</regdate></item><item><carelesscause>음식물 조리중</carelesscause><fire>377</fire><regdate>09</regdate></item><item><carelesscause>담배꽁초</carelesscause><fire>231</fire><regdate>08</regdate></item><item><carelesscause>빨래삶기</carelesscause><fire>17<
# ...
