# %%
import pandas as pd

# %%
df=pd.read_csv("서울시 소방대상물 위치정보 (좌표계 _ WGS1984).csv")

# %%
df
# Out:
#             순번      대상물ID   서소코드   대상물번호              대상물이름 대형화재대상구분 위험물ID  \
# 0            1  839107002  83252     140              우광덕건물        N
# 1            2  808612010  80251     141               평산빌딩        N
# 2            3  888511010  88253     142               송일빌딩        N
# 3            4  758008001  75252     151              이응행건물        N
# 4            5  888208006  88253     151               거보빌딩        N
# 5            6  888307005  88253     153               동주빌딩        N
# 6            8  768605001  76250     155              김성식건물        N
# 7            9  758412011  75252     159               영희빌딩        N
# 8           10  767809002  76250     160       영수빌딩(구 영인빌딩)        N
# 9           11  739110001  73252     162              강정식건물        N
# 10          12  739207001  73252     163               덕수빌딩        N
# 11          13  839002002  83253     164               동산빌딩        N
# ...
